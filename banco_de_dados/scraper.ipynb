# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import numpy as np
from time import sleep
import re
import copy

# %%
Placeholder=None#To handle missing values when scraping
Headers={'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:84.0) Gecko/20100101 Firefox/84.0'}

# %%
movie_name=[]
movie_year=[]
movie_rating=[]
movie_votes=[]
movie_metascore=[]
Gross_income=[]
Movie_Runtime=[]
Genre=[]
Age_rated=[]
Directors=[]
Stars=[]
description=[]

# %%
import time
start=time.time()
pages=np.arange(1,10000,50)
for page in pages:
    url=f'https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&sort=user_rating,desc&start={str(page)}'
    try:
        webpage = requests.get(url, headers=Headers).text
    except requests.exceptions.ConnectionError:
        print(f"Connection error occurred. Retrying after 5 sec")
        time.sleep(5)  # Wait for 5 seconds before retrying
        continue  # Skip the rest of the loop and move to the next page

    # webpage=requests.get(url,headers=Headers).text
    soup=BeautifulSoup(webpage,'lxml')
    movie_data=soup.find_all("div",class_="lister-item mode-advanced")
    print(f"Scraping URL: {url}")

    for movies in movie_data:
        #Movie name
        movie_name.append(movies.h3.a.text.strip())

        #Years
        years=movies.h3.find("span",class_='lister-item-year text-muted unbold').text.strip("()")
        movie_year.append(years)



        #Rating
        rate=movies.find('div', class_ = 'inline-block ratings-imdb-rating').text.replace('\n', '')
        movie_rating.append(rate)

        #Meta Score
        meta = movies.find('span', class_ = 'metascore').text.replace(' ', '') if movies.find('span', class_ = 'metascore') else Placeholder
        movie_metascore.append(meta)

        #Gross income and Votes

        value = movies.find_all('span', attrs = {'name': "nv"})

        vote = value[0].text
        gross = value[1].text if len(value)>1 else Placeholder#handling missing value
        Gross_income.append(gross)
        movie_votes.append(vote)


        #Runtime,Genre and Certificate

        runtime_span = movies.find("span", class_="runtime")
        genre_span = movies.find("span", class_="genre")
        certificate_span = movies.find("span", class_="certificate")

            # Handle missing runtime information
        if runtime_span:
            runtime_text = runtime_span.text.strip('min')
        else:
            runtime_text = Placeholder

            # Handle missing genre information
        if genre_span:
            genre_text = genre_span.text.strip().split(',')
        else:
            genre_text = [Placeholder]

             # Handle missing certificate information
        if certificate_span:
            certificate_text = certificate_span.text.strip()
        else:
            certificate_text = Placeholder


        #Description

        Movie_Runtime.append(runtime_text)
        Genre.append(genre_text)
        Age_rated.append(certificate_text)

        describe = movies.find_all('p', class_ = 'text-muted')
        description_ = describe[1].text.replace('\n', '') if len(describe) >1 else Placeholder
        description.append(description_)


        #Director and Stars using Regex
        Cast = movies.find('p', class_='').text.strip().replace('\n', '')

              # Extract directors and stars using regex patterns
        directors_pattern = r"Directors?:(.*?)(?:\||Stars:|$)"
        stars_pattern = r"Stars:(.*?)(?:\||$)"

              # Extract directors using regex
        directors_match = re.search(directors_pattern, Cast, re.DOTALL)
        directors = [director.strip() for director in directors_match.group(1).split(',')] if directors_match else []

              # Extract stars using regex
        stars_match = re.search(stars_pattern, Cast, re.DOTALL)
        stars = [star.strip() for star in stars_match.group(1).split(',')] if stars_match else []

        Directors.append(directors)
        Stars.append(stars)

end=time.time()
total=end-start
print(total)
# Out:
# Scraping URL: https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&sort=user_rating,desc&start=1
# Scraping URL: https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&sort=user_rating,desc&start=51
# Scraping URL: https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&sort=user_rating,desc&start=101
# Scraping URL: https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&sort=user_rating,desc&start=151
# Scraping URL: https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&sort=user_rating,desc&start=201
# Scraping URL: https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&sort=user_rating,desc&start=251
# Scraping URL: https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&sort=user_rating,desc&start=301
# Scraping URL: https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&sort=user_rating,desc&start=351
# Scraping URL: https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&sort=user_rating,desc&start=401
# Scraping URL: https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&sort=user_rating,desc&start=451
# Scraping URL: https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&sort=user_rating,desc&start=501
# Scraping URL: https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&sort=user_rating,desc&start=551
# Scraping URL: https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&sort=user_rating,desc&start=601
# Scraping URL: https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&sort=user_rating,desc&start=651
# Scraping URL: https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&sort=user_rating,desc&start=701
# Scraping URL: https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&sort=user_rating,desc&start=751
# Scraping URL: https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&sort=user_rating,desc&start=801
# Scraping URL: https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&sort=user_rating,desc&start=851
# Scraping URL: https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&sort=user_rating,desc&start=901
# Scraping URL: https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&sort=user_rating,desc&start=951
# Scraping URL: https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&sort=user_rating,desc&start=1001
# Scraping URL: https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&sort=user_rating,desc&start=1051
# Scraping URL: https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&sort=user_rating,desc&start=1101
# Scraping URL: https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&sort=user_rating,desc&start=1151
# Scraping URL: https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&sort=user_rating,desc&start=1201
# Scraping URL: https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&sort=user_rating,desc&start=1251
# Scraping URL: https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&sort=user_rating,desc&start=1301
# Scraping URL: https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&sort=user_rating,desc&start=1351
# Scraping URL: https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&sort=user_rating,desc&start=1401
# Scraping URL: https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&sort=user_rating,desc&start=1451
# Scraping URL: https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&sort=user_rating,desc&start=1501
# Scraping URL: https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&sort=user_rating,desc&start=1551
# Scraping URL: https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&sort=user_rating,desc&start=1601
# Scraping URL: https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&sort=user_rating,desc&start=1651
# Scraping URL: https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&sort=user_rating,desc&start=1701
# Scraping URL: https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&sort=user_rating,desc&start=1751
# Scraping URL: https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&sort=user_rating,desc&start=1801
# Scraping URL: https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&sort=user_rating,desc&start=1851
# Scraping URL: https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&sort=user_rating,desc&start=1901
# Scraping URL: https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&sort=user_rating,desc&start=1951
# Scraping URL: https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&sort=user_rating,desc&start=2001
# Scraping URL: https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&sort=user_rating,desc&start=2051
# Scraping URL: https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&sort=user_rating,desc&start=2101
# Scraping URL: https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&sort=user_rating,desc&start=2151
# Scraping URL: https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&sort=user_rating,desc&start=2201
# Scraping URL: https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&sort=user_rating,desc&start=2251
# Scraping URL: https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&sort=user_rating,desc&start=2301
# Scraping URL: https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&sort=user_rating,desc&start=2351
# Scraping URL: https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&sort=user_rating,desc&start=2401
# Scraping URL: https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&sort=user_rating,desc&start=2451
# Scraping URL: https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&sort=user_rating,desc&start=2501
# Scraping URL: https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&sort=user_rating,desc&start=2551
# Scraping URL: https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&sort=user_rating,desc&start=2601
# Scraping URL: https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&sort=user_rating,desc&start=2651
# Scraping URL: https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&sort=user_rating,desc&start=2701
# Scraping URL: https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&sort=user_rating,desc&start=2751
# Scraping URL: https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&sort=user_rating,desc&start=2801
# Scraping URL: https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&sort=user_rating,desc&start=2851
# Scraping URL: https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&sort=user_rating,desc&start=2901
# Scraping URL: https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&sort=user_rating,desc&start=2951
# Scraping URL: https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&sort=user_rating,desc&start=3001
# Scraping URL: https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&sort=user_rating,desc&start=3051
# Scraping URL: https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&sort=user_rating,desc&start=3101
# Scraping URL: https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&sort=user_rating,desc&start=3151
# Scraping URL: https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&sort=user_rating,desc&start=3201
# Scraping URL: https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&sort=user_rating,desc&start=3251
# Scraping URL: https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&sort=user_rating,desc&start=3301
# Scraping URL: https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&sort=user_rating,desc&start=3351
# Scraping URL: https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&sort=user_rating,desc&start=3401
# Scraping URL: https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&sort=user_rating,desc&start=3451
# Scraping URL: https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&sort=user_rating,desc&start=3501
# Scraping URL: https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&sort=user_rating,desc&start=3551
# Scraping URL: https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&sort=user_rating,desc&start=3601
# Scraping URL: https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&sort=user_rating,desc&start=3651
# Scraping URL: https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&sort=user_rating,desc&start=3701
# Scraping URL: https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&sort=user_rating,desc&start=3751
# Scraping URL: https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&sort=user_rating,desc&start=3801
# Scraping URL: https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&sort=user_rating,desc&start=3851
# Scraping URL: https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&sort=user_rating,desc&start=3901
# Scraping URL: https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&sort=user_rating,desc&start=3951
# Scraping URL: https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&sort=user_rating,desc&start=4001
# Scraping URL: https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&sort=user_rating,desc&start=4051
# Scraping URL: https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&sort=user_rating,desc&start=4101
# Scraping URL: https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&sort=user_rating,desc&start=4151
# Scraping URL: https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&sort=user_rating,desc&start=4201
# Scraping URL: https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&sort=user_rating,desc&start=4251
# Scraping URL: https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&sort=user_rating,desc&start=4301
# Scraping URL: https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&sort=user_rating,desc&start=4351
# Scraping URL: https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&sort=user_rating,desc&start=4401
# Scraping URL: https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&sort=user_rating,desc&start=4451
# Scraping URL: https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&sort=user_rating,desc&start=4501
# Scraping URL: https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&sort=user_rating,desc&start=4551
# Scraping URL: https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&sort=user_rating,desc&start=4601
# Scraping URL: https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&sort=user_rating,desc&start=4651
# Scraping URL: https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&sort=user_rating,desc&start=4701
# Scraping URL: https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&sort=user_rating,desc&start=4751
# Scraping URL: https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&sort=user_rating,desc&start=4801
# Scraping URL: https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&sort=user_rating,desc&start=4851
# Scraping URL: https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&sort=user_rating,desc&start=4901
# Scraping URL: https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&sort=user_rating,desc&start=4951
# Scraping URL: https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&sort=user_rating,desc&start=5001
# Scraping URL: https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&sort=user_rating,desc&start=5051
# Scraping URL: https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&sort=user_rating,desc&start=5101
# Scraping URL: https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&sort=user_rating,desc&start=5151
# Scraping URL: https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&sort=user_rating,desc&start=5201
# Scraping URL: https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&sort=user_rating,desc&start=5251
# Scraping URL: https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&sort=user_rating,desc&start=5301
# Scraping URL: https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&sort=user_rating,desc&start=5351
# Scraping URL: https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&sort=user_rating,desc&start=5401
# Scraping URL: https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&sort=user_rating,desc&start=5451
# Scraping URL: https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&sort=user_rating,desc&start=5501
# Scraping URL: https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&sort=user_rating,desc&start=5551
# Scraping URL: https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&sort=user_rating,desc&start=5601
# Scraping URL: https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&sort=user_rating,desc&start=5651
# Scraping URL: https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&sort=user_rating,desc&start=5701
# Scraping URL: https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&sort=user_rating,desc&start=5751
# Scraping URL: https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&sort=user_rating,desc&start=5801
# Scraping URL: https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&sort=user_rating,desc&start=5851
# Scraping URL: https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&sort=user_rating,desc&start=5901
# Scraping URL: https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&sort=user_rating,desc&start=5951
# Scraping URL: https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&sort=user_rating,desc&start=6001
# Scraping URL: https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&sort=user_rating,desc&start=6051
# Scraping URL: https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&sort=user_rating,desc&start=6101
# Scraping URL: https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&sort=user_rating,desc&start=6151
# Scraping URL: https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&sort=user_rating,desc&start=6201
# Scraping URL: https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&sort=user_rating,desc&start=6251
# Scraping URL: https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&sort=user_rating,desc&start=6301
# Scraping URL: https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&sort=user_rating,desc&start=6351
# Scraping URL: https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&sort=user_rating,desc&start=6401
# Scraping URL: https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&sort=user_rating,desc&start=6451
# Scraping URL: https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&sort=user_rating,desc&start=6501
# Scraping URL: https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&sort=user_rating,desc&start=6551
# Scraping URL: https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&sort=user_rating,desc&start=6601
# Scraping URL: https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&sort=user_rating,desc&start=6651
# Scraping URL: https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&sort=user_rating,desc&start=6701
# Scraping URL: https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&sort=user_rating,desc&start=6751
# Scraping URL: https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&sort=user_rating,desc&start=6801
# Scraping URL: https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&sort=user_rating,desc&start=6851
# Scraping URL: https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&sort=user_rating,desc&start=6901
# Scraping URL: https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&sort=user_rating,desc&start=6951
# Scraping URL: https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&sort=user_rating,desc&start=7001
# Scraping URL: https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&sort=user_rating,desc&start=7051
# Scraping URL: https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&sort=user_rating,desc&start=7101
# Scraping URL: https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&sort=user_rating,desc&start=7151
# Scraping URL: https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&sort=user_rating,desc&start=7201
# Scraping URL: https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&sort=user_rating,desc&start=7251
# Scraping URL: https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&sort=user_rating,desc&start=7301
# Scraping URL: https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&sort=user_rating,desc&start=7351
# Scraping URL: https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&sort=user_rating,desc&start=7401
# Scraping URL: https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&sort=user_rating,desc&start=7451
# Scraping URL: https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&sort=user_rating,desc&start=7501
# Scraping URL: https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&sort=user_rating,desc&start=7551
# Scraping URL: https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&sort=user_rating,desc&start=7601
# Scraping URL: https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&sort=user_rating,desc&start=7651
# Scraping URL: https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&sort=user_rating,desc&start=7701
# Scraping URL: https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&sort=user_rating,desc&start=7751
# Scraping URL: https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&sort=user_rating,desc&start=7801
# Scraping URL: https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&sort=user_rating,desc&start=7851
# Scraping URL: https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&sort=user_rating,desc&start=7901
# Scraping URL: https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&sort=user_rating,desc&start=7951
# Scraping URL: https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&sort=user_rating,desc&start=8001
# Scraping URL: https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&sort=user_rating,desc&start=8051
# Scraping URL: https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&sort=user_rating,desc&start=8101
# Scraping URL: https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&sort=user_rating,desc&start=8151
# Scraping URL: https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&sort=user_rating,desc&start=8201
# Scraping URL: https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&sort=user_rating,desc&start=8251
# Scraping URL: https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&sort=user_rating,desc&start=8301
# Scraping URL: https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&sort=user_rating,desc&start=8351
# Scraping URL: https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&sort=user_rating,desc&start=8401
# Scraping URL: https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&sort=user_rating,desc&start=8451
# Scraping URL: https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&sort=user_rating,desc&start=8501
# Scraping URL: https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&sort=user_rating,desc&start=8551
# Scraping URL: https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&sort=user_rating,desc&start=8601
# Scraping URL: https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&sort=user_rating,desc&start=8651
# Scraping URL: https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&sort=user_rating,desc&start=8701
# Scraping URL: https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&sort=user_rating,desc&start=8751
# Scraping URL: https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&sort=user_rating,desc&start=8801
# Scraping URL: https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&sort=user_rating,desc&start=8851
# Scraping URL: https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&sort=user_rating,desc&start=8901
# Scraping URL: https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&sort=user_rating,desc&start=8951
# Scraping URL: https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&sort=user_rating,desc&start=9001
# Scraping URL: https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&sort=user_rating,desc&start=9051
# Scraping URL: https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&sort=user_rating,desc&start=9101
# Scraping URL: https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&sort=user_rating,desc&start=9151
# Scraping URL: https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&sort=user_rating,desc&start=9201
# Scraping URL: https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&sort=user_rating,desc&start=9251
# Scraping URL: https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&sort=user_rating,desc&start=9301
# Scraping URL: https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&sort=user_rating,desc&start=9351
# Scraping URL: https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&sort=user_rating,desc&start=9401
# Scraping URL: https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&sort=user_rating,desc&start=9451
# Scraping URL: https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&sort=user_rating,desc&start=9501
# Scraping URL: https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&sort=user_rating,desc&start=9551
# Scraping URL: https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&sort=user_rating,desc&start=9601
# Scraping URL: https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&sort=user_rating,desc&start=9651
# Scraping URL: https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&sort=user_rating,desc&start=9701
# Scraping URL: https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&sort=user_rating,desc&start=9751
# Scraping URL: https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&sort=user_rating,desc&start=9801
# Scraping URL: https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&sort=user_rating,desc&start=9851
# Scraping URL: https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&sort=user_rating,desc&start=9901
# Scraping URL: https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&sort=user_rating,desc&start=9951
# 250.5342469215393

# %%
Dataset = pd.DataFrame({
    "Movie Name": movie_name, "Year of Release" : movie_year, "Run Time in minutes": Movie_Runtime,"Movie Rating": movie_rating,"Votes":movie_votes,"MetaScore":movie_metascore,
    "Gross":Gross_income,"Genre":Genre,"Certification":Age_rated,"Director":Directors,"Stars":Stars,"Description":description
})

# %%
data = pd.DataFrame(columns = Dataset.columns, data = copy.deepcopy(Dataset.values))

# %%
data['Year of Release']=data['Year of Release'].str.replace(r'\D', '').astype(int)#Removes all the unwanted values with regex \D  and changes them into int
data.Votes=data.Votes.str.replace(',','').astype(int)
data['Movie Rating']=data['Movie Rating'].astype(float)
data['Run Time in minutes']=data['Run Time in minutes'].astype(int)

for index,value in enumerate(data.Gross):
  if value!=None:
    data.Gross[index]=value.replace('$','').replace('M','')
data.Gross=pd.to_numeric(data.Gross)
data.Gross=data.Gross*1000000

data.MetaScore=pd.to_numeric(data.MetaScore)
# Out:
# <ipython-input-311-497fe3c909c0>:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   data['Year of Release']=data['Year of Release'].str.replace(r'\D', '').astype(int)#Removes all the unwanted values with regex \D  and changes them into int
# <ipython-input-311-497fe3c909c0>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.Gross[index]=value.replace('$','').replace('M','')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Movie Name           10000 non-null  object
#  1   Year of Release      10000 non-null  int64
#  2   Run Time in minutes  10000 non-null  int64
#  3   Movie Rating         10000 non-null  float64
#  4   Votes                10000 non-null  int64
#  5   MetaScore            7974 non-null   float64
#  6   Gross                7085 non-null   float64
#  7   Genre                10000 non-null  object
#  8   Certification        9631 non-null   object
#  9   Director             10000 non-null  object
#  10  Stars                10000 non-null  object
#  11  Description          10000 non-null  object
# dtypes: float64(3), int64(3), object(6)
# memory usage: 937.6+ KB

# %%
data['Description']=data['Description'].apply(lambda x:x.split())

# %%
data
# Out:
#                                Movie Name  Year of Release  \
# 0                The Shawshank Redemption             1994
# 1                           The Godfather             1972
# 2     Ramayana: The Legend of Prince Rama             1993
# 3                         The Chaos Class             1975
# 4                         The Dark Knight             2008
# ...                                   ...              ...
# 9995                        Golmaal Again             2017
# 9996                        Not to Forget             2021
# 9997                          Housefull 3             2016
# 9998                          A.I. Rising             2018
# 9999                         The Last Boy             2019
#
#       Run Time in minutes  Movie Rating    Votes  MetaScore        Gross  \
# 0                     142           9.3  2804443       82.0   28340000.0
# 1                     175           9.2  1954174      100.0  134970000.0
# 2                     135           9.2    12995        NaN          NaN
# 3                      87           9.2    42231        NaN          NaN
# 4                     152           9.0  2786129       84.0  534860000.0
# ...                   ...           ...      ...        ...          ...
# 9995                  140           4.9    10183        NaN    1010000.0
# 9996                   84           4.9    11191        NaN          NaN
# 9997                  140           4.9    10308        NaN    1160000.0
# 9998                   85           4.9    11187        NaN          NaN
# 9999                   87           4.9    10324        NaN          NaN
#
#                                  Genre Certification  \
# 0                              [Drama]             R
# 1                      [Crime,  Drama]             R
# 2     [Animation,  Action,  Adventure]            PG
# 3                     [Comedy,  Drama]          None
# 4             [Action,  Crime,  Drama]         PG-13
# ...                                ...           ...
# 9995       [Action,  Comedy,  Fantasy]     Not Rated
# 9996                           [Drama]          None
# 9997       [Action,  Comedy,  Romance]     Not Rated
# 9998        [Drama,  Romance,  Sci-Fi]             R
# 9999      [Fantasy,  Mystery,  Sci-Fi]          None
#
#                                   Director  \
# 0                         [Frank Darabont]
# 1                   [Francis Ford Coppola]
# 2     [Ram Mohan, Yûgô Sakô, Koichi Saski]
# 3                          [Ertem Egilmez]
# 4                      [Christopher Nolan]
# ...                                    ...
# 9995                        [Rohit Shetty]
# 9996                      [Valerio Zanoli]
# 9997                 [Sajid, Farhad Samji]
# 9998                       [Lazar Bodroza]
# 9999                       [Perry Bhandal]
#
#                                                   Stars  \
# 0     [Tim Robbins, Morgan Freeman, Bob Gunton, Will...
# 1     [Marlon Brando, Al Pacino, James Caan, Diane K...
# 2     [Arun Govil, Nikhil Kapoor, Edie Mirman, Rael ...
# 3     [Kemal Sunal, Münir Özkul, Halit Akçatepe, Tar...
# 4     [Christian Bale, Heath Ledger, Aaron Eckhart, ...
# ...                                                 ...
# 9995  [Ajay Devgn, Arshad Warsi, Tabu, Shreyas Talpade]
# 9996  [Karen Grassle, Louis Gossett Jr., Tatum O'Nea...
# 9997  [Akshay Kumar, Abhishek Bachchan, Riteish Desh...
# 9998  [Sebastian Cavazza, Stoya, Marusa Majer, Kirst...
# 9999  [Luke Goss, Flynn Allen, Peter Guinness, Matil...
#
#                                             Description
# 0     [Over, the, course, of, several, years,, two, ...
# 1     [Don, Vito, Corleone,, head, of, a, mafia, fam...
# 2     [An, anime, adaptation, of, the, Hindu, epic, ...
# 3     [Lazy,, uneducated, students, share, a, very, ...
# 4     [When, the, menace, known, as, the, Joker, wre...
# ...                                                 ...
# 9995  [The, gang, encounters, with, some, spiritual,...
# 9996  [After, a, lifetime, of, scams,, a, self-cente...
# 9997  [A, father, doesn't, want, his, three, daughte...
# 9998  [An, intimate, relationship, between, a, human...
# 9999  [With, the, world's, end, imminent,, a, dying,...
#
# [10000 rows x 12 columns]

# %%
data.to_csv("Movies_IMDB.csv")
